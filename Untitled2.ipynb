# %% [markdown]
# <a href="https://colab.research.google.com/github/marschenone/Proyecto-Final-Schenone/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

os.chdir('..')
# !ls
# Out:
# bin			    datalab  lib     media		       proc	   sbin  tools
# boot			    dev      lib32   mnt		       python-apt  srv	 usr
# content			    etc      lib64   NGC-DL-CONTAINER-LICENSE  root	   sys	 var
# cuda-keyring_1.0-1_all.deb  home     libx32  opt		       run	   tmp

# %%
# Conectar Drive a Colab
from google.colab import drive
import os

# Montar drive
drive.mount("/content/drive/")
# Cambiar directorio
os.chdir('/content/drive/MyDrive/Colab Notebooks/Data/')
# Out:
# Mounted at /content/drive/

# %%
df_delitos = pd.read_csv('snic-robos-provincias-series.csv')

# %%
df_delitos.describe()
# Out:
#        indice_tiempo  robos_hechos_buenos_aires  robos_hechos_caba  \
# count      22.000000                  22.000000          22.000000
# mean     2011.500000               97568.227273       74683.090909
# std         6.493587               27085.972676       11782.383347
# min      2001.000000               58863.000000       40178.000000
# 25%      2006.250000               80185.000000       72983.500000
# 50%      2011.500000               94719.000000       75991.000000
# 75%      2016.750000              112744.000000       83027.750000
# max      2022.000000              155512.000000       91763.000000
#
#        robos_hechos_catamarca  robos_hechos_chaco  robos_hechos_chubut  \
# count               22.000000           22.000000            22.000000
# mean              4518.272727         7388.954545          4760.818182
# std               1460.642526         1956.734196           724.271498
# min               2527.000000         4433.000000          2971.000000
# ...

# %%
df_delitos.head()
# Out:
#    indice_tiempo  robos_hechos_buenos_aires  robos_hechos_caba  \
# 0           2001                     118351              72868
# 1           2002                     153518              75283
# 2           2003                     131978              76618
# 3           2004                      97113              74054
# 4           2005                      64252              74773
#
#    robos_hechos_catamarca  robos_hechos_chaco  robos_hechos_chubut  \
# 0                    2527               11163                 2971
# 1                    3667               12822                 3772
# 2                    3437                9231                 5060
# 3                    3182                8565                 4773
# 4                    2968                8052                 4475
#
#    robos_hechos_cordoba  robos_hechos_corrientes  robos_hechos_entre_rios  \
# 0                 43168                     9168                     6347
# ...

# %%
df_delitos.columns
# Out:
# Index(['indice_tiempo', 'robos_hechos_buenos_aires', 'robos_hechos_caba',
#        'robos_hechos_catamarca', 'robos_hechos_chaco', 'robos_hechos_chubut',
#        'robos_hechos_cordoba', 'robos_hechos_corrientes',
#        'robos_hechos_entre_rios', 'robos_hechos_formosa', 'robos_hechos_jujuy',
#        'robos_hechos_la_pampa', 'robos_hechos_la_rioja',
#        'robos_hechos_mendoza', 'robos_hechos_misiones', 'robos_hechos_neuquen',
#        'robos_hechos_rio_negro', 'robos_hechos_salta', 'robos_hechos_san_juan',
#        'robos_hechos_san_luis', 'robos_hechos_santa_cruz',
#        'robos_hechos_santa_fe', 'robos_hechos_sgo_estero',
#        'robos_hechos_tierra_fuego', 'robos_hechos_tucuman',
#        'robos_tasa_buenos_aires', 'robos_tasa_caba', 'robos_tasa_catamarca',
#        'robos_tasa_chaco', 'robos_tasa_chubut', 'robos_tasa_cordoba',
#        'robos_tasa_corrientes', 'robos_tasa_entre_rios', 'robos_tasa_formosa',
# ...

# %%
df_delitos.shape
# Out:
# (22, 49)

# %%
df_delitos.info
# Out:
# <bound method DataFrame.info of     indice_tiempo  robos_hechos_buenos_aires  robos_hechos_caba  \
# 0            2001                     118351              72868
# 1            2002                     153518              75283
# 2            2003                     131978              76618
# 3            2004                      97113              74054
# 4            2005                      64252              74773
# 5            2006                      58863              81587
# 6            2007                      59560              86851
# 7            2008                      77413              91763
# 8            2009                      63145              85782
# 9            2010                      71299              84310
# 10           2011                      88501              83761
# 11           2012                      94059              83508
# 12           2013                      95379              76559
# ...

# %%
df_delitos['robos_hechos_buenos_aires'].unique
# Out:
# <bound method Series.unique of 0     118351
# 1     153518
# 2     131978
# 3      97113
# 4      64252
# 5      58863
# 6      59560
# 7      77413
# 8      63145
# 9      71299
# 10     88501
# 11     94059
# 12     95379
# 13     99744
# 14     91761
# 15     91522
# 16     92512
# 17    105185
# 18    155512
# 19    115916
# 20    115029
# 21    105889
# Name: robos_hechos_buenos_aires, dtype: int64>
